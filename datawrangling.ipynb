# %%
import pandas as pd

# %%
hpa_df = pd.read_csv("https://www.proteinatlas.org/download/proteinatlas.tsv.zip", compression="zip", sep="\t")
nonPathology_id_vars = [col for col in hpa_df.columns if col.startswith('Pathology prognostics') == False]
hpa_df = hpa_df.melt(id_vars=nonPathology_id_vars, var_name="pathology", value_name="prognostic")
nonBloodConc_id_vars = [col for col in hpa_df.columns if col.startswith('Blood concentration') == False]
hpa_df = hpa_df.melt(id_vars=nonBloodConc_id_vars, var_name="bloodConcType", value_name="bloodConc")
nonExpressionCluster_id_vars = [col for col in hpa_df.columns if col.endswith('expression cluster') == False]
hpa_df = hpa_df.melt(id_vars=nonExpressionCluster_id_vars, var_name="expressionClusterType", value_name="expressionCluster")

# %%
hpa_df
# Out:
#                Gene                          Gene synonym          Ensembl  \
# 0            TSPAN6                 T245, TM4SF6, TSPAN-6  ENSG00000000003
# 1              TNMD  BRICD4, ChM1L, myodulin, TEM, tendin  ENSG00000000005
# 2              DPM1                           CDGIE, MPDS  ENSG00000000419
# 3             SCYL3                         PACE-1, PACE1  ENSG00000000457
# 4          C1orf112                              FLJ10706  ENSG00000000460
# ...             ...                                   ...              ...
# 2732235  AC105206.4                                   NaN  ENSG00000288677
# 2732236  AL136115.4                                   NaN  ENSG00000288678
# 2732237  AC136475.9                                   NaN  ENSG00000288681
# 2732238  AL353671.1                                   NaN  ENSG00000288684
# 2732239  AC064824.1                                   NaN  ENSG00000288695
#
#                                           Gene description Uniprot Chromosome  \
# 0                                            Tetraspanin 6  O43657          X
# 1                                              Tenomodulin  Q9H2S6          X
# 2        Dolichyl-phosphate mannosyltransferase subunit...  O60762         20
# 3                                 SCY1 like pseudokinase 3  Q8IZE3          1
# 4                      Chromosome 1 open reading frame 112  Q9NSG2          1
# ...                                                    ...     ...        ...
# 2732235                                      Novel protein     NaN          8
# 2732236                                      Novel protein     NaN          1
# 2732237                                      Novel protein     NaN         11
# 2732238                                      Novel protein     NaN          9
# 2732239     Novel protein, SRD5A3-RP11-177J6.1 readthrough     NaN          4
#
#                     Position  \
# 0        100627108-100639991
# 1        100584936-100599885
# 2          50934867-50958555
# 3        169849631-169894267
# 4        169662007-169854080
# ...                      ...
# 2732235    22130604-22130708
# 2732236    31919563-31919628
# 2732237        308408-315272
# 2732238    32455323-32552603
# 2732239    55346228-55388368
#
#                                              Protein class Biological process  \
# 0        Predicted intracellular proteins, Predicted me...                NaN
# 1                              Predicted membrane proteins                NaN
# 2        Disease related genes, Enzymes, Human disease ...                NaN
# 3                Enzymes, Predicted intracellular proteins                NaN
# 4                         Predicted intracellular proteins                NaN
# ...                                                    ...                ...
# 2732235                   Predicted intracellular proteins                NaN
# 2732236                   Predicted intracellular proteins                NaN
# 2732237                        Predicted membrane proteins                NaN
# 2732238                   Predicted intracellular proteins                NaN
# 2732239                        Predicted membrane proteins                NaN
#
#                        Molecular function  ... CCD Transcript  \
# 0                                     NaN  ...            NaN
# 1                                     NaN  ...            NaN
# 2        Glycosyltransferase, Transferase  ...            NaN
# 3                                     NaN  ...            NaN
# 4                                     NaN  ...            NaN
# ...                                   ...  ...            ...
# 2732235                               NaN  ...            NaN
# 2732236                               NaN  ...            NaN
# 2732237                               NaN  ...            NaN
# 2732238                               NaN  ...            NaN
# 2732239                               NaN  ...            NaN
#
#         Subcellular main location Subcellular additional location  \
# 0         Cell Junctions, Cytosol       Nucleoli fibrillar center
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3                    Microtubules                  Nuclear bodies
# 4                    Mitochondria                             NaN
# ...                           ...                             ...
# 2732235                       NaN                             NaN
# 2732236                       NaN                             NaN
# 2732237                       NaN                             NaN
# 2732238  Plasma membrane, Cytosol                             NaN
# 2732239                       NaN                             NaN
#
#                                          Antibody RRID  \
# 0                                HPA004109: AB_1080301
# 1        HPA034961: AB_10670285, HPA055634: AB_2682868
# 2                                HPA051818: AB_2681624
# 3                                HPA005624: AB_1854916
# 4         HPA023778: AB_1848665, HPA024451: AB_1848667
# ...                                                ...
# 2732235                                            NaN
# 2732236                                            NaN
# 2732237                                            NaN
# 2732238             HPA047193: AB_2679978, HPA073217:
# 2732239                                            NaN
#
#                                          pathology              prognostic  \
# 0            Pathology prognostics - Breast cancer  unprognostic (7.71e-2)
# 1            Pathology prognostics - Breast cancer  unprognostic (3.60e-2)
# 2            Pathology prognostics - Breast cancer  unprognostic (2.21e-2)
# 3            Pathology prognostics - Breast cancer  unprognostic (2.35e-1)
# 4            Pathology prognostics - Breast cancer  unprognostic (4.97e-2)
# ...                                            ...                     ...
# 2732235  Pathology prognostics - Urothelial cancer                     NaN
# 2732236  Pathology prognostics - Urothelial cancer                     NaN
# 2732237  Pathology prognostics - Urothelial cancer                     NaN
# 2732238  Pathology prognostics - Urothelial cancer                     NaN
# 2732239  Pathology prognostics - Urothelial cancer                     NaN
#
#                                        bloodConcType  bloodConc  \
# 0        Blood concentration - Conc. blood IM [pg/L]        NaN
# 1        Blood concentration - Conc. blood IM [pg/L]        NaN
# 2        Blood concentration - Conc. blood IM [pg/L]        NaN
# 3        Blood concentration - Conc. blood IM [pg/L]        NaN
# 4        Blood concentration - Conc. blood IM [pg/L]        NaN
# ...                                              ...        ...
# 2732235  Blood concentration - Conc. blood MS [pg/L]        NaN
# 2732236  Blood concentration - Conc. blood MS [pg/L]        NaN
# 2732237  Blood concentration - Conc. blood MS [pg/L]        NaN
# 2732238  Blood concentration - Conc. blood MS [pg/L]        NaN
# 2732239  Blood concentration - Conc. blood MS [pg/L]        NaN
#
#                   expressionClusterType  \
# 0              Blood expression cluster
# 1              Blood expression cluster
# 2              Blood expression cluster
# 3              Blood expression cluster
# 4              Blood expression cluster
# ...                                 ...
# 2732235  Single cell expression cluster
# 2732236  Single cell expression cluster
# 2732237  Single cell expression cluster
# 2732238  Single cell expression cluster
# 2732239  Single cell expression cluster
#
#                                     expressionCluster
# 0              Cluster 32: T-cells - Unknown function
# 1                                                 NaN
# 2          Cluster 39: Non-specific - mRNA processing
# 3        Cluster 41: Basophils - Cellular respiration
# 4                Cluster 15: NK-cells - Transcription
# ...                                               ...
# 2732235                                           NaN
# 2732236                                           NaN
# 2732237                                           NaN
# 2732238      Cluster 61: Non-specific - Transcription
# 2732239        Cluster 5: Bronchus - Unknown function
#
# [2732240 rows x 69 columns]
